# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv('GSE99622_hanamsagar2017_raw_reads.txt', delimiter = '\t')

# %%
for i in range(len(df)):
    if df['Best'][i] == 0:
        df.drop(i, axis = 0, inplace = True)

# %%
df.drop(columns = {'Transcript', 'Best'}, inplace = True)

# %%
df.set_index('Gene', inplace = True)

# %%
df.to_csv('GSE99622_hanamsagar2017_raw_reads.csv')

# %%
degs = pd.read_csv('combined_degs.csv', index_col = 0)

# %%
degs[degs['padj'] < 0.05]
# Out:
#                  baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# Baz2b          130.047791       -0.545884  0.146624 -3.723030  1.968464e-04
# Tmem204         34.581509        0.920410  0.230731  3.989097  6.632538e-05
# Zscan22         12.264420        0.601638  0.216343  2.780948  5.420041e-03
# Atp8b1          21.679423       -0.802591  0.252848 -3.174198  1.502510e-03
# Tpm4           219.031684       -1.159180  0.158928 -7.293764  3.014139e-13
# ...                   ...             ...       ...       ...           ...
# 4930487H11Rik    1.701605       -2.714335  0.754766 -3.596260  3.228251e-04
# Gm17066         99.124284       -1.295980  0.144550 -8.965627  3.085199e-19
# 2310014F07Rik    5.931808       -4.096423  0.509994 -8.032303  9.565973e-16
# Gm15987          1.224775       -3.295243  0.885056 -3.723205  1.967099e-04
# Gdap10          13.876076       -1.379640  0.308050 -4.478625  7.512532e-06
#
#                        padj
# ...

# %%
lps_index = pd.read_csv('C:\\Users\\Ben\\Dropbox\\bilbo_lab_spr2020\\microglia-seq_website\\microglia-seq\\lps_index\\combined_lps_index.csv', index_col = 0)

# %%
lps_index = lps_index[lps_index['pvals'] < 0.05]

# %%
print(len(np.intersect1d(lps_index.index, degs.index)), 'genes are shared between females and combined')
# Out:
# 2741 genes are shared between females and combined

# %%
degs = degs[degs['pvalue'] < 0.05]

# %%
degs
# Out:
#                  baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# BC031181        69.673427        0.478768  0.199119  2.404435  0.016197
# Baz2b          130.047791       -0.545884  0.146624 -3.723030  0.000197
# Tmem204         34.581509        0.920410  0.230731  3.989097  0.000066
# Ccdc111         58.492587       -0.399605  0.176393 -2.265421  0.023487
# Zscan22         12.264420        0.601638  0.216343  2.780948  0.005420
# ...                   ...             ...       ...       ...       ...
# Snhg5           37.651998       -0.527622  0.222638 -2.369864  0.017795
# Gm15987          1.224775       -3.295243  0.885056 -3.723205  0.000197
# Gdap10          13.876076       -1.379640  0.308050 -4.478625  0.000008
# 2610019E17Rik    1.548569        1.802436  0.723689  2.490621  0.012752
# 5730480H06Rik    2.064651       -1.058302  0.505926 -2.091811  0.036455
#
#                    padj
# BC031181       0.098279
# Baz2b          0.002781
# Tmem204        0.001075
# ...

# %%
degs_male = pd.read_csv('male_degs.csv', index_col = 0)
degs_female = pd.read_csv('female_degs.csv', index_col = 0)

# %%
degs_male = degs_male[degs_male['padj'] < 0.05]

# %%
degs_female = degs_female[degs_female['padj'] < 0.05]

# %%
print(len(np.intersect1d(degs_male.index, degs_female.index)))
# Out:
# 435

# %%
degs_male
# Out:
#                  baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# Ccdc148          9.244963        1.393390  0.529640  2.630824  8.517813e-03
# Baz2b          164.488808       -0.788410  0.143305 -5.501635  3.762862e-08
# Tmem204         35.031397        1.217412  0.315200  3.862350  1.123017e-04
# Ccdc111         65.562695       -0.851416  0.240756 -3.536423  4.055855e-04
# Ttyh1            7.788247        1.569973  0.552068  2.843805  4.457832e-03
# ...                   ...             ...       ...       ...           ...
# 2310014F07Rik    6.421863       -3.987207  0.756547 -5.270270  1.362234e-07
# 4933433G15Rik    2.072531       -2.580342  0.988585 -2.610137  9.050586e-03
# Snhg5           40.365093       -1.091764  0.294258 -3.710229  2.070719e-04
# Gm15987          1.710063       -4.200503  1.369136 -3.067995  2.155004e-03
# Gdap10          18.602632       -2.495129  0.353950 -7.049373  1.797255e-12
#
#                        padj
# ...
