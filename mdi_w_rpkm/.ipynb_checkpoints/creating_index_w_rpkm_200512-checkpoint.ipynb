# %% [markdown]
# ## Trying to create the MDI with the RPKM adjusted gene values, let's see if it lines up!!!

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
df = pd.read_csv('GSE99622_hanamsagar2017_rpkm_unmelted.csv', index_col = 0, header = [0, 1, 2, 3])

# %%
### (expression value of the gene in a sample—minimum expression for the gene across all samples)/(maximum expression for the gene across all
### samples—minimum expression for the gene across all samples),
### scale all values so that they add equal weight to the index

def scale_expression(df):
    scaled_expression_df = df.copy()

    for row in range(len(scaled_expression_df)):
        scaled_expression_df.iloc[row] = (scaled_expression_df.iloc[row] - np.min(scaled_expression_df.iloc[row])) / np.max(scaled_expression_df.iloc[row] - np.min(scaled_expression_df.iloc[row]))
        
        
    return scaled_expression_df

# %%
scaled_df = scale_expression(df)

# %%
scaled_df
# Out:
#                     E18                                     P14            \
#                  Female      Male    Female      Male    Female
#                     SAL       SAL       SAL       SAL       SAL
#                 F_E18 1   M_E18 1   F_E18 3   M_E18 4   F_P14 1   F_P14 2
# gene
# Scap           0.481716  1.000000  0.588925  0.291011  0.464168  0.509930
# Taf9b          0.280798  0.376208  0.371928  0.092616  0.302889  0.302273
# BC031181       0.122368  0.338887  0.144314  1.000000  0.011651  0.065336
# Baz2b          0.548646  0.366839  0.488163  0.000000  0.487904  0.550477
# Tmem204        0.320381  0.135444  0.107174  0.707995  0.452977  0.568683
# ...                 ...       ...       ...       ...       ...       ...
# 4930592A05Rik  0.168251  0.059876  0.140325  0.723327  0.246806  0.449740
# Gm10336        0.226142  0.221469  0.232974  0.000000  0.517424  0.476064
# 2810013P06Rik  0.854034  0.878970  0.864906  0.670562  0.255814  0.414381
# 4931403E22Rik  0.678685  0.259346  0.320384  0.293224  0.634853  0.517118
# 4930549G23Rik  0.904118  0.230684  0.336252  0.703268  0.463713  0.132905
#
#                                                        ...   P60 + LPS  \
#                                                        ...      Female
#                                                        ...         LPS
#                 F_P14 3   F_P14 4   F_P14 5   F_P14 6  ... F_P60_LPS 3
# gene                                                   ...
# Scap           0.530751  0.495134  0.470869  0.363178  ...    0.567889
# Taf9b          0.688249  0.316869  0.844004  0.581683  ...    0.000000
# BC031181       0.058856  0.007997  0.130694  0.083144  ...    0.031200
# Baz2b          0.453857  0.543584  0.372060  0.462410  ...    0.923518
# Tmem204        0.616790  0.328277  0.554494  0.275194  ...    0.605630
# ...                 ...       ...       ...       ...  ...         ...
# 4930592A05Rik  0.539575  0.280213  0.671343  0.530519  ...    0.608150
# Gm10336        0.437787  0.366645  0.248015  0.490265  ...    0.462658
# 2810013P06Rik  0.409709  0.513285  0.491190  0.120860  ...    0.346047
# 4931403E22Rik  0.663368  0.153203  0.516779  0.462065  ...    0.800254
# 4930549G23Rik  0.480419  0.335779  0.523485  0.362263  ...    0.000000
#
#                                                                       P60  \
#                      Male                                            Male
#                       LPS                                             SAL
#               M_P60_LPS 3 M_P60_LPS 4 M_P60_LPS 5 M_P60_LPS 6 M_P60_Sal 1
# gene
# Scap             0.208036    0.270097    0.334136    0.348901    0.414752
# Taf9b            0.441592    0.794405    0.397151    0.517619    0.655402
# BC031181         0.092472    0.054081    0.071367    0.041399    0.129514
# Baz2b            1.000000    0.772993    0.719651    0.784436    0.502850
# Tmem204          0.000000    0.109641    0.221135    0.550087    0.599223
# ...                   ...         ...         ...         ...         ...
# 4930592A05Rik    0.179349    0.346226    0.223382    0.278613    0.675231
# Gm10336          1.000000    0.402886    0.506112    0.519046    0.425024
# 2810013P06Rik    0.238540    0.302375    0.217875    0.514168    0.384971
# 4931403E22Rik    0.204228    0.246093    0.694302    0.949256    0.427563
# 4930549G23Rik    0.708021    0.102990    0.333505    0.246469    0.281678
#
#
#                                                        Female
#                                                           SAL
#               M_P60_Sal 2 M_P60_Sal 3 M_P60_Sal 4 F_P60_Sal 6
# gene
# Scap             0.550100    0.555784    0.406527    0.000000
# Taf9b            0.153650    0.620713    0.576484    1.000000
# BC031181         0.039895    0.194189    0.136442    0.467554
# Baz2b            0.514594    0.417431    0.397554    0.288922
# Tmem204          0.609693    0.612312    0.823308    1.000000
# ...                   ...         ...         ...         ...
# 4930592A05Rik    0.223988    0.806546    0.674659    1.000000
# Gm10336          0.535492    0.378954    0.455880    0.243349
# 2810013P06Rik    0.243399    0.362253    0.381226    0.080490
# 4931403E22Rik    0.394046    0.429425    0.405356    0.226868
# 4930549G23Rik    0.107197    0.511667    0.082212    0.775969
#
# [9431 rows x 60 columns]

# %%
def identify_significant_genes(df):
    
    e18_all= df['E18']
    p60 = df['P60']
    
    p60_all = p60.iloc[:, p60.columns.get_level_values(1)=='SAL']

    pvals = np.zeros(shape = len(df))
    sig = np.zeros(shape = len(df))
    logdiff = np.zeros(shape = len(df))

    for row in range(len(df)):
        pvals[row] = stats.ttest_ind(e18_all.iloc[row], p60_all.iloc[row])[1]
        sig[row] = stats.ttest_ind(e18_all.iloc[row], p60_all.iloc[row])[0]
        logdiff[row] = np.log2(np.mean(p60_all.iloc[row])/np.mean(e18_all.iloc[row]))
    df['pvals'] = pvals
    df['sig'] = sig
    df['logdiff'] = logdiff

    direction = [0] * len(df)
    for row in range(len(df)):
        if df['pvals'][row] < 0.05:
            if df['logdiff'][row] > 0:
                direction[row] = 'UP'
            else:
                direction[row] = 'DOWN'
        else:
            direction[row] = 'N/A'
    df['direction'] = direction
    

    return df

# %%
new_df = identify_significant_genes(scaled_df)

# %%
def remove_unsignificant_rows(df):
    df.reset_index(inplace = True)
    for row in range(len(df)):
        if df['direction'][row] == 'N/A':
            df.drop(row, inplace = True)  
    df.reset_index(drop=True, inplace=True)
    return df

# %%
df_cleaned = remove_unsignificant_rows(new_df)

# %%
down_genes = df_cleaned['gene'][df_cleaned['direction'] == 'DOWN'].to_list()
up_genes = df_cleaned['gene'][df_cleaned['direction'] == 'UP'].to_list()

# %%
def generate_index(df):
    
    samples = df.columns[1:-4]
    
    index_per_sample = [0] * len(samples)
    i = -1
    
    for sample in samples:
        i = i + 1
        index_per_sample[i] = np.mean(df[sample][df['direction'] == 'UP']) / np.mean(df[sample][df['direction'] == 'DOWN'])
        
    return index_per_sample

# %%
final_df = pd.DataFrame([generate_index(df_cleaned)], columns = df_cleaned.columns[1:-4])
final_df
# Out:
#         E18                                     P14                     \
#      Female      Male    Female      Male    Female
#         SAL       SAL       SAL       SAL       SAL
#     F_E18 1   M_E18 1   F_E18 3   M_E18 4   F_P14 1  F_P14 2   F_P14 3
# 0  0.465999  0.295727  0.467145  0.113086  1.471928  1.50442  1.316481
#
#                                 ...   P60 + LPS                          \
#                                 ...      Female        Male
#                                 ...         LPS         LPS
#     F_P14 4  F_P14 5   F_P14 6  ... F_P60_LPS 3 M_P60_LPS 3 M_P60_LPS 4
# 0  1.498605  1.05133  1.414031  ...    2.440531    3.252065    2.254667
#
#                                   P60                                      \
#                                  Male
#                                   SAL
#   M_P60_LPS 5 M_P60_LPS 6 M_P60_Sal 1 M_P60_Sal 2 M_P60_Sal 3 M_P60_Sal 4
# 0    2.288352    2.835702    2.270407    2.464408     1.71139     1.90627
#
#
#        Female
#           SAL
#   F_P60_Sal 6
# 0    1.906664
#
# [1 rows x 60 columns]

# %%
## scale data to between 0 and 1
final_df_scaled = pd.DataFrame(final_df.iloc[0] - np.min(final_df.iloc[0])) / (np.max(final_df.iloc[0] - np.min(final_df.iloc[0])))
final_df_scaled.reset_index(inplace = True)

# %%
final_df_scaled
# Out:
#       level_0 level_1 level_2      level_3         0
# 0         E18  Female     SAL      F_E18 1  0.105351
# 1         E18    Male     SAL      M_E18 1  0.054521
# 2         E18  Female     SAL      F_E18 3  0.105693
# 3         E18    Male     SAL      M_E18 4  0.000000
# 4         P14  Female     SAL      F_P14 1  0.405637
# 5         P14  Female     SAL      F_P14 2  0.415337
# 6         P14  Female     SAL      F_P14 3  0.359234
# 7         P14  Female     SAL      F_P14 4  0.413601
# 8         P14  Female     SAL      F_P14 5  0.280082
# 9         P14  Female     SAL      F_P14 6  0.388354
# 10        P14  Female     SAL      F_P14 7  0.423472
# 11        P14  Female     SAL      F_P14 8  0.609911
# 12        P14  Female     SAL      F_P14 9  0.524940
# 13        P14  Female     SAL     F_P14 10  0.565900
# 14         P4    Male     SAL       M_P4 1  0.185509
# 15         P4  Female     SAL       F_P4 2  0.262375
# 16         P4  Female     SAL       F_P4 3  0.263839
# 17         P4  Female     SAL       F_P4 4  0.270223
# 18  P60 + LPS  Female     LPS  F_P60_LPS 1  0.839416
# 19  P60 + LPS  Female     LPS  F_P60_LPS 2  0.615865
# 20  P60 + LPS    Male     LPS  M_P60_LPS 2  0.963430
# 21  P60 + LPS  Female     LPS  F_P60_LPS 4  0.540771
# 22  P60 + LPS  Female     LPS  F_P60_LPS 5  0.605205
# 23  P60 + LPS  Female     LPS  F_P60_LPS 6  0.574988
# 24  P60 + LPS    Male     LPS  M_P60_LPS 7  0.828130
# 25        P60  Female     SAL  F_P60_Sal 1  0.774915
# 26        P60  Female     SAL  F_P60_Sal 2  0.714274
# 27        P60  Female     SAL  F_P60_Sal 3  0.718391
# 28        P60  Female     SAL  F_P60_Sal 4  0.874920
# 29        P60  Female     SAL  F_P60_Sal 5  1.000000
# 30        P60    Male     SAL  M_P60_Sal 5  0.702712
# 31        P60  Female     SAL  F_P60_Sal 7  0.673790
# 32        E18  Female     SAL      F_E18 2  0.046335
# 33        E18    Male     SAL      M_E18 2  0.079766
# 34        E18    Male     SAL      M_E18 3  0.049678
# 35        P14    Male     SAL      M_P14 1  0.533195
# 36        P14    Male     SAL      M_P14 2  0.460036
# 37        P14    Male     SAL      M_P14 3  0.475667
# 38        P14    Male     SAL      M_P14 4  0.408304
# 39        P14    Male     SAL      M_P14 5  0.345718
# 40        P14    Male     SAL      M_P14 6  0.354013
# 41        P14    Male     SAL      M_P14 7  0.361867
# 42        P14    Male     SAL      M_P14 8  0.518746
# 43        P14    Male     SAL      M_P14 9  0.625870
# 44        P14    Male     SAL     M_P14 10  0.546461
# 45         P4  Female     SAL       F_P4 1  0.209371
# 46         P4    Male     SAL       M_P4 2  0.246174
# 47         P4    Male     SAL       M_P4 3  0.217396
# 48         P4    Male     SAL       M_P4 4  0.315367
# 49  P60 + LPS    Male     LPS  M_P60_LPS 1  0.772770
# 50  P60 + LPS  Female     LPS  F_P60_LPS 3  0.694782
# 51  P60 + LPS    Male     LPS  M_P60_LPS 3  0.937039
# 52  P60 + LPS    Male     LPS  M_P60_LPS 4  0.639298
# 53  P60 + LPS    Male     LPS  M_P60_LPS 5  0.649354
# 54  P60 + LPS    Male     LPS  M_P60_LPS 6  0.812747
# 55        P60    Male     SAL  M_P60_Sal 1  0.643997
# 56        P60    Male     SAL  M_P60_Sal 2  0.701910
# 57        P60    Male     SAL  M_P60_Sal 3  0.477121
# 58        P60    Male     SAL  M_P60_Sal 4  0.535296
# 59        P60  Female     SAL  F_P60_Sal 6  0.535414

# %%
final_df_scaled.columns = ['age', 'sex', 'tx', 'sample_name', 'index']

# %%
final_df_scaled.to_csv('C:\\Users\\Ben\\Dropbox\\bilbo_lab_spr2020\\microglia-seq_website\\microglia-seq\\mdi\\rpkm_data_index.csv')

# %%
regulated_genes = pd.DataFrame((dict([ (k,pd.Series(v)) for k,v in {'gene' : df_cleaned['index'], 'direction' : df_cleaned['direction'], 'valence' : df_cleaned['logdiff']}.items() ])))

regulated_genes.to_csv('C:\\Users\\Ben\\Dropbox\\bilbo_lab_spr2020\\microglia-seq_website\\microglia-seq\\mdi\\rpkm_data_index_gene_list.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-2a5a1bf49052> in <module>
# ----> 1 regulated_genes = pd.DataFrame((dict([ (k,pd.Series(v)) for k,v in {'gene' : df_cleaned['index'], 'direction' : df_cleaned['direction'], 'valence' : df_cleaned['logdiff']}.items() ])))
#       2
#       3 regulated_genes.to_csv('C:\\Users\\Ben\\Dropbox\\bilbo_lab_spr2020\\microglia-seq_website\\microglia-seq\\mdi\\rpkm_data_index_gene_list.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2797         if is_single_key:
#    2798             if self.columns.nlevels > 1:
# -> 2799                 return self._getitem_multilevel(key)
#    2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    2847     def _getitem_multilevel(self, key):
#    2848         # self.columns is a MultiIndex
# -> 2849         loc = self.columns.get_loc(key)
#    2850         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2851             new_columns = self.columns[loc]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2660         if not isinstance(key, (tuple, list)):
#    2661             # not including list here breaks some indexing, xref #30892
# -> 2662             loc = self._get_level_indexer(key, level=0)
#    2663             return _maybe_to_slice(loc)
#    2664
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2927         else:
#    2928
# -> 2929             code = self._get_loc_single_level_index(level_index, key)
#    2930
#    2931             if level > 0 or self.lexsort_depth == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2596             return -1
#    2597         else:
# -> 2598             return level_index.get_loc(key)
#    2599
#    2600     def get_loc(self, key, method=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
